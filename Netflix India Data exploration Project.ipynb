# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
#loading data
df = pd.read_csv("netfix_cleaned.csv")
df
# Out:
#                         names  release_year maturity_rating duration  \
# 0               Mission Majnu          2023        U/A 16+     2h 9m
# 1                      Cirkus          2022         U/A 7+    2h 14m
# 2         Gangubai Kathiawadi          2022        U/A 16+    2h 33m
# 3                     Thunivu          2023        U/A 16+    2h 22m
# 4           Bhool Bhulaiyaa 2          2022        U/A 13+    2h 21m
# ..                        ...           ...             ...      ...
# 555            Happy New Year          2014        U/A 13+    2h 58m
# 556               RRR (Hindi)          2022              A     3h 5m
# 557            Major (Telugu)          2022        U/A 16+    2h 25m
# 558              Om Shanti Om          2007        U/A 16+    2h 48m
# 559  Kabhi Khushi Kabhie Gham          2001        U/A 13+    3h 29m
#
#                                            description  \
# 0    In the 1970s, an undercover Indian spy takes o...
# ...

# %%
df.head()
# Out:
#                  names  release_year maturity_rating duration  \
# 0        Mission Majnu          2023        U/A 16+     2h 9m
# 1               Cirkus          2022         U/A 7+    2h 14m
# 2  Gangubai Kathiawadi          2022        U/A 16+    2h 33m
# 3              Thunivu          2023        U/A 16+    2h 22m
# 4    Bhool Bhulaiyaa 2          2022        U/A 13+    2h 21m
#
#                                          description  \
# 0  In the 1970s, an undercover Indian spy takes o...
# 1  Chaos and comedy take the spotlight when a rin...
# 2  Duped and sold to a brothel, a young woman fea...
# 3  A major bank heist takes an unnerving turn whe...
# 4  When strangers Reet and Ruhan cross paths, the...
#
#                                                genre         mood  \
# 0  ['Spy Movies', 'Hindi-Language Movies', 'Bolly...  Suspenseful
# 1  ['Hindi-Language Movies', 'Bollywood Movies', ...        Goofy
# 2  ['Hindi-Language Movies', 'Movies Based on Boo...  Provocative
# ...

# %%
df.shape
# Out:
# (560, 10)

# %%
df.tail()
# Out:
#                         names  release_year maturity_rating duration  \
# 555            Happy New Year          2014        U/A 13+    2h 58m
# 556               RRR (Hindi)          2022              A     3h 5m
# 557            Major (Telugu)          2022        U/A 16+    2h 25m
# 558              Om Shanti Om          2007        U/A 16+    2h 48m
# 559  Kabhi Khushi Kabhie Gham          2001        U/A 13+    3h 29m
#
#                                            description  \
# 555  A revenge-seeking diamond thief gathers a ragt...
# 556  A fearless warrior on a perilous mission comes...
# 557  This biopic follows the life of Indian Army of...
# 558  Reincarnated 30 years after being killed in a ...
# 559  Years after his father disowns his adopted bro...
#
#                                                  genre             mood  \
# 555  ['Hindi-Language Movies', 'Bollywood Movies', ...        Feel-Good
# ...

# %%
df.describe()
# Out:
#        release_year
# count    560.000000
# mean    2016.521429
# std        6.282517
# min     1993.000000
# 25%     2012.000000
# 50%     2019.000000
# 75%     2022.000000
# max     2023.000000

# %%
df.columns
# Out:
# Index(['names', 'release_year', 'maturity_rating', 'duration', 'description',
#        'genre', 'mood', 'cast', 'subtitles', 'audio'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# names               0
# release_year        0
# maturity_rating     0
# duration            0
# description         0
# genre               0
# mood               43
# cast                0
# subtitles           0
# audio               0
# dtype: int64

# %%
# count() simply returns the number of non NaN/Null values in column (series) you apply it on.
df['mood'].count()
# Out:
# 517

# %%
# value_counts() aggregates the data and counts each unique value. 
# You can achieve the same by using groupby which is a more broad function to aggregate data in pandas.
df['mood'].value_counts()
# Out:
# Exciting            90
# Emotional,          39
# Adrenaline Rush,    32
# Heartfelt,          25
# Goofy               24
# Feel-Good,          19
# Suspenseful,        19
# Goofy,              17
# Violent,            17
# Witty,              15
# Ominous,            15
# Quirky,             14
# Adrenaline Rush     14
# Sentimental,        14
# Feel-Good           13
# Mind-Bending,       13
# Heartfelt           11
# Dark,               11
# Suspenseful         10
# Gritty,              9
# Offbeat,             8
# Quirky               8
# Emotional            8
# Inspiring,           7
# Offbeat              7
# Chilling,            6
# Intimate             5
# Charming,            5
# Sentimental          4
# Bittersweet,         4
# Witty                4
# Romantic             4
# Exciting,            3
# Violent              3
# Intimate,            3
# Scary,               2
# Steamy,              2
# Dark                 2
# Raunchy              2
# Scary                2
# ...

# %%
df.groupby("mood")['release_year'].count()
# Out:
# mood
# Adrenaline Rush     14
# Adrenaline Rush,    32
# Bittersweet,         4
# Charming,            5
# Chilling,            6
# Dark                 2
# Dark,               11
# Emotional            8
# Emotional,          39
# Exciting            90
# Exciting,            3
# Feel-Good           13
# Feel-Good,          19
# Goofy               24
# Goofy,              17
# Gritty               1
# Gritty,              9
# Heartfelt           11
# Heartfelt,          25
# Inspiring,           7
# Intimate             5
# Intimate,            3
# Mind-Bending         1
# Mind-Bending,       13
# Offbeat              7
# Offbeat,             8
# Ominous              1
# Ominous,            15
# Provocative          2
# Quirky               8
# Quirky,             14
# Raunchy              2
# Romantic             4
# Scary                2
# Scary,               2
# Sentimental          4
# Sentimental,        14
# Steamy,              2
# Suspenseful         10
# ...

# %%
df['genre'].value_counts()
# Out:
# ['Family Features', 'US Movies', 'Children & Family Movies', 'Comedies']                             55
# ['Family Features', 'US Movies', 'Movies Based on Books', 'Children & Family Movies', 'Comedies']    29
# ['Action & Adventure']                                                                               23
# ['Sci-Fi Movies', 'US Movies', 'Action & Adventure']                                                 20
# ['US Movies', 'Action & Adventure']                                                                  16
#                                                                                                      ..
# ['US Movies', 'Action & Adventure', 'Comedies']                                                       1
# ['US Movies', 'Period Pieces', 'Movies Based on Books', 'Action & Adventure', 'Dramas']               1
# ['Mysteries', 'US Movies', 'Crime Movies', 'Thriller Movies']                                         1
# ...

# %%
df['maturity_rating'].value_counts()
# Out:
# U/A 7+      186
# U/A 13+     178
# U/A 16+     123
# A            69
# U             4
# Name: maturity_rating, dtype: int64

# %%
df['release_year'].value_counts()
# Out:
# 2022    160
# 2021     63
# 2020     35
# 2018     32
# 2011     30
# 2013     28
# 2019     22
# 2016     20
# 2015     20
# 2010     15
# 2008     14
# 2023     13
# 2012     13
# 2005     12
# 2017     12
# 2007     12
# 2014     12
# 2004     11
# 2006     11
# 2009      9
# 1993      3
# 2001      3
# 1999      3
# 2002      2
# 2003      2
# 1994      2
# 2000      1
# Name: release_year, dtype: int64

# %%
df['duration'].value_counts()
# Out:
# 1h 37m    19
# 1h 29m    18
# 2h 6m     18
# 1h 49m    18
# 2h 14m    15
#           ..
# 2h 32m     1
# 2h 45m     1
# 2h 1m      1
# 48m        1
# 3h 29m     1
# Name: duration, Length: 93, dtype: int64

# %%
#Visually representing the data
x = ['Exciting','Emotional','Adrenaline Rush','Heartfelt','Goofy','Feel-Good','Suspenseful','Goofy','Violent','Witty']
y = [90,39,32,25,24,19,19,17,17,15]
plt.barh(x,y,color='g')
plt.title("Top moods in Netflix")
plt.xlabel("mood")
plt.ylabel("shows")
plt.show()

# %%
#Years with most netflix shows in relesaed year
x=['2022','2021','2020','2018','2011','2013','2019','2016','2015','2010']
y=[160,63,35,32,30,28,22,20,20,15]
plt.bar(x,y,color="y")
plt.title("Years with most netflix shows release_year")
plt.xlabel("Release year")
plt.ylabel("No. of Shows released")
plt.show()
